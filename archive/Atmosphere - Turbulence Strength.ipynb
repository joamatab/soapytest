# %%
import numpy
from astropy.io import fits
import os
# %matplotlib notebook
from matplotlib import pyplot
import bokeh.plotting as bplot
bplot.output_notebook()
# Out:
#     <script type="text/javascript">
#
#       (function(global) {
#         function now() {
#           return new Date();
#         }
#
#         if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#           window._bokeh_onload_callbacks = [];
#         }
#
#         function run_callbacks() {
#           window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#           delete window._bokeh_onload_callbacks
#           console.info("Bokeh: all callbacks have finished");
#         }
#
#         function load_libs(js_urls, callback) {
#           window._bokeh_onload_callbacks.push(callback);
#           if (window._bokeh_is_loading > 0) {
#             console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#             return null;
#           }
#           if (js_urls == null || js_urls.length === 0) {
#             run_callbacks();
#             return null;
#           }
#           console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#           window._bokeh_is_loading = js_urls.length;
#           for (var i = 0; i < js_urls.length; i++) {
#             var url = js_urls[i];
#             var s = document.createElement('script');
#             s.src = url;
#             s.async = false;
#             s.onreadystatechange = s.onload = function() {
#               window._bokeh_is_loading--;
#               if (window._bokeh_is_loading === 0) {
#                 console.log("Bokeh: all BokehJS libraries loaded");
#                 run_callbacks()
#               }
#             };
#             s.onerror = function() {
#               console.warn("failed to load library " + url);
#             };
#             console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#             document.getElementsByTagName("head")[0].appendChild(s);
#           }
#         };var js_urls = ['https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.js', 'https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.js', 'https://cdn.pydata.org/bokeh/release/bokeh-compiler-0.11.0.min.js'];
#
#         var inline_js = [
#           function(Bokeh) {
#             Bokeh.set_log_level("info");
#           },
#           function(Bokeh) {
#             console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.css");
#             Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.css");
#             console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.css");
#             Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.css");
#           }
#         ];
#
#         function run_inline_js() {
#           for (var i = 0; i < inline_js.length; i++) {
#             inline_js[i](window.Bokeh);
#           }
#         }
#
#         if (window._bokeh_is_loading === 0) {
#           console.log("Bokeh: BokehJS loaded, going straight to plotting");
#           run_inline_js();
#         } else {
#           load_libs(js_urls, function() {
#             console.log("Bokeh: BokehJS plotting callback run at", now());
#             run_inline_js();
#           });
#         }
#       }(this));
#     </script>
#     <div>
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span>BokehJS successfully loaded.</span>
#     </div>

# %%
from aotools.circle import zernike
from soapy import atmosphere, confParse

# %%
SOAPY_CONF = "conf/test_conf.py"

# %%
config = confParse.Configurator(SOAPY_CONF)
config.loadSimParams()

config.atmos.wholeScrnSize = 4096
config.atmos.scrnNo = 1

NZERNS = 30
NR0s = 10
NIters = 5000
RUNS = 5
R0s = numpy.linspace(0.05, 0.5, NR0s)

print("Telescope Diameters:{}".format(config.tel.telDiam))
# Out:
# Telescope Diameters:8.0

# %%
# Make the zernike to use in advance
Zs = zernike.zernikeArray(NZERNS+1, config.sim.pupilSize)
piston = Zs[0]
Zs = Zs[1:]
Zs.shape = NZERNS, config.sim.pupilSize**2

# %%
# Test the large screen travelling over the telescope
# Buffer to store zernike coeffs
zCoeffs = numpy.zeros((NR0s, NIters*RUNS, NZERNS))

sCoord = int(round((config.sim.scrnSize-config.sim.pupilSize)/2)) # Coordinate to get middle of phase screen
for ir0, r0 in enumerate(R0s):
    print("Do Run with r0: {}".format(r0))
    config.atmos.r0 = r0
    for irun in range(RUNS):
        atmos = atmosphere.atmos(config.sim, config.atmos)
        for i in range(NIters):
            scrn = atmos.moveScrns()[0]
            subScrn = scrn[sCoord:-sCoord, sCoord:-sCoord] * (2*numpy.pi/500.)
            subScrn = subScrn.reshape(config.sim.pupilSize**2)
            # Get z coeffs
            zCoeffs[ir0, irun*NIters + i] = (Zs*subScrn).sum(1)/piston.sum()
# Out:
# Do Run with r0: 0.05
# Do Run with r0: 0.266666666667
# Do Run with r0: 0.483333333333
# Do Run with r0: 0.7
# Do Run with r0: 0.916666666667
# Do Run with r0: 1.13333333333
# Do Run with r0: 1.35
# Do Run with r0: 1.56666666667
# Do Run with r0: 1.78333333333
# Do Run with r0: 2.0

# %%
zVars = zCoeffs.var(1)

# %%
# Load the noll reference values
noll = fits.getdata("resources/noll.fits").diagonal()[:NZERNS]

# %%
pyplot.figure()
pyplot.semilogy(noll, label="Noll")
for ir0, r0 in enumerate(R0s):
    pyplot.semilogy(zVars[ir0], label="r0:{}".format(r0))
pyplot.legend()
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ## measuredR0s = config.tel.telDiam/ ((zVars[:,2:]/noll[2:]).mean(1))**(3/5.)

# %%
plt = bplot.figure()
plt.line(R0s, measuredR0s, legend="Measured")
plt.line(R0s, R0s, color="k", legend="Theoretical")
bplot.show(plt)
# Out:
#     <div class="plotdiv" id="9cbd011f-7916-484f-b437-ed1aef8ba492"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("9cbd011f-7916-484f-b437-ed1aef8ba492");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '9cbd011f-7916-484f-b437-ed1aef8ba492' but no matching script tag was found. ")
#       return false;
#     }var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"b3d87216-1713-4e3d-8790-330f41b32178": {"version": "0.11.0", "roots": {"root_ids": ["768bf9fc-d8b5-4bd2-af43-f0367ca8d3a6", "45b7cae9-5098-41d0-89c6-e8392175b0a2", "768bdfb1-b2e6-4028-86a0-819343ce010e", "0410d7f1-63fb-42f0-a7ed-e05fa262a285", "ae4d9b6f-9567-4d0b-a66d-bf1a0193ce0b", "e6d0c6e1-6485-49cb-a267
}, {"attributes": {"line_color": {"value": "#1f77b4"}, "line_alpha": {"value": 0.1}, "x": {"field": "x"}}, "type": "Line", "id": "b868740b-cf29-4a21-9d96-c5cc7f34c371"}, {"attributes": {"callback": null, "column_names": ["x"], "data": {"x": [0.448626309633255, 0.448626309633255, 0.023204809054732323, 0.023204809054732323, 0.023204809054732323, 0.006187949329614639, 0.006187949329614639, 0.006187949329614639, 0.006187949329614639, 0.0024525 ...

# %%
zVars.shape
# Out:
# (10, 30)

# %%
zCoeffs.shape
# Out:
# (10, 25000, 30)

# %%
# Test random screen generation
# Buffer to store zernike coeffs
zCoeffs = numpy.zeros((NR0s, NIters*RUNS, NZERNS))
config.atmos.randomScrns = True
sCoord = int(round((config.sim.scrnSize-config.sim.pupilSize)/2)) # Coordinate to get middle of phase screen
for ir0, r0 in enumerate(R0s):
    print("Do Run with r0: {}".format(r0))
    config.atmos.r0 = r0
    atmos = atmosphere.atmos(config.sim, config.atmos)
    for i in range(NIters*RUNS):
        scrn = atmos.moveScrns()[0]
        subScrn = scrn[sCoord:-sCoord, sCoord:-sCoord] * (2*numpy.pi/500.)
        subScrn = subScrn.reshape(config.sim.pupilSize**2)
        # Get z coeffs
        zCoeffs[ir0, i] = (Zs*subScrn).sum(1)/piston.sum()
# Out:
# Do Run with r0: 0.05
# Do Run with r0: 0.266666666667
# Do Run with r0: 0.483333333333
# Do Run with r0: 0.7
# Do Run with r0: 0.916666666667
# Do Run with r0: 1.13333333333
# Do Run with r0: 1.35
# Do Run with r0: 1.56666666667
# Do Run with r0: 1.78333333333
# Do Run with r0: 2.0

# %%
zVars = zCoeffs.var(1)

# %%
pyplot.figure()
pyplot.semilogy(noll, label="Noll")
for ir0, r0 in enumerate(R0s):
    pyplot.semilogy(zVars[ir0], label="r0:{}".format(r0))
pyplot.legend()
# Out:
# <img src="data:image/png;base64,...">

# %%
measuredR0s = config.tel.telDiam/ ((zVars[:,2:]/noll[2:]).mean(1))**(3/5.)

# %%
plt = bplot.figure()
plt.line(R0s, measuredR0s, legend="Measured")
plt.line(R0s, R0s, color="k", legend="Theoretical")
bplot.show(plt)
# Out:
#     <div class="plotdiv" id="d8681be0-ad31-4823-adf0-f52d5edfb02f"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d8681be0-ad31-4823-adf0-f52d5edfb02f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd8681be0-ad31-4823-adf0-f52d5edfb02f' but no matching script tag was found. ")
#       return false;
#     }var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"11c32c4c-74e0-496a-abd5-31d14ce3fc97": {"version": "0.11.0", "roots": {"root_ids": ["768bf9fc-d8b5-4bd2-af43-f0367ca8d3a6", "45b7cae9-5098-41d0-89c6-e8392175b0a2", "768bdfb1-b2e6-4028-86a0-819343ce010e", "0410d7f1-63fb-42f0-a7ed-e05fa262a285", "ae4d9b6f-9567-4d0b-a66d-bf1a0193ce0b", "e6d0c6e1-6485-49cb-a267-709c51f49fb3", "542c0cce-739d-44f9-8df5-f51687171f08", "e9a5ff33-3cae-4c12-bd34-a2d426e62167", "0c6511c6-df3a-4385-9305-839981de2632", "8c5d9e3f-3d5d-4ff3-9c92-4e9af12252f1", "a0ed2220-7144-4846-86ea-bd81739805dd", "bddb60b6-7163-4f9f-9eed-d56f004542e1", "6dbcbb86-188b-4989-b72e-d312c981017b", "4316559a-e467-4b02-b9f4-9d3de923221b", "cdc29b2a-5e4b-44ac-ac05-b7d6da661172", "9f1f4559-4e36-4573-ab85-c9133d5d3295", "2f5dc3f6-6d24-4ae7-abb9-e8111ae2cbde", "60f9af99-c146-45ba-aeb1-f337f4d0ddf4", "f2b5b04b-6265-4678-8a2f-f4011f5c2d1d"], "references": [{"attributes": {"line_color": {"value": "#1f77b4"}, "line_alpha": {"value": 0.1}, "x": {"field": "x"}}, "type": "Line", "id": "dcc42066-fa49-4755-8757-fec8379d708d"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "542c0cce-739d-44f9-8df5-f51687171f08"}, "overlay": {"type": "BoxAnnotation", "id": "f59e03f9-9e65-46dd-9df3-66a90e4a97be"}}, "type": "BoxZoomTool", "id": "72766554-27c1-4126-b73b-f8994155c3db"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "e6d0c6e1-6485-49cb-a267-709c51f49fb3"}, "formatter": {"type": "BasicTickFormatter", "id": "6071608c-662d-419d-b7a3-c49fab6f6347"}, "ticker": {"type": "BasicTicker", "id": "cb854f56-c0e0-41a1-8767-c314a78d0c9e"}}, "type": "LinearAxis", "id": "2ed99832-8978-4d27-ae38-491b7dcafc8a"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "ae4d9b6f-9567-4d0b-a66d-bf1a0193ce0b"}}, "type": "ResizeTool", "id": "3d44c397-bf3e-4767-a029-0ee331a0c68e"}, {"attributes": {"line_color": {"value": "#1f77b4"}, "line_alpha": {"value": 0.1}, "x": {"field": "x"}}, "type": "Line", "id": "ee68b0c1-5038-403a-b994-23e1afcbe13f"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "4316559a-e467-4b02-b9f4-9d3de923221b"}}, "type": "WheelZoomTool", "id": "933fb47e-ace0-4195-a2b4-6bf5a2014f02"}, {"attributes": {}, "type": "BasicTickFormatter", "id": "e1426d4b-50df-45b2-aa4a-e826cb9e2685"}, {"attributes": {"line_color": {"value": "#1f77b4"}, "x": {"field": "x"}}, "type": "Line", "id": "310ee868-5c15-4ed0-a66e-aa39523d6d2e"}, {"attributes": {"callback": null, "column_names": ["y", "x"], "data": {"y": [0.05, 0.26666666666666666, 0.48333333333333334, 0.7000000000000001, 0.9166666666666667, 1.1333333333333335, 1.35, 1.5666666666666667, 1.7833333333333334, 2.0], "x": [0.05, 0.26666666666666666, 0.48333333333333334, 0.7000000000000001, 0.9166666666666667, 1.1333333333333335, 1.35, 1.5666666666666667, 1.7833333333333334, 2.0]}}, "type": "ColumnDataSource", "id": "0d7b0958-627e-43dc-bd8a-ce50dc532940"}, {"attributes": {}, "type": "BasicTickFormatter", "id": "8287c6e2-08bc-48ea-bf18-a16a27f0f699"}, {"attributes": {}, "type": "BasicTicker", "id": "eac2ec2b-d8d2-4b00-99e7-750e3147340d"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "0c6511c6-df3a-4385-9305-839981de2632"}, "overlay": {"type": "BoxAnnotation", "id": "1ae131aa-92e7-414d-b9cd-7040625958e5"}}, "type": "BoxZoomTool", "id": "c053ffae-4f53-44b7-a982-b134edd72508"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "ae4d9b6f-9567-4d0b-a66d-bf1a0193ce0b"}, "formatter": {"type": "BasicTickFormatter", "id": "9c0856fb-f7af-4ff8-84b8-4e22477ac991"}, "ticker": {"type": "BasicTicker", "id": "60287640-15d6-4127-9e31-7ea12bb0b6b8"}}, "type": "LinearAxis", "id": "975c5a76-3237-4bf9-8e8c-be4706a3f0d4"}, {"attributes": {}, "type": "BasicTicker", "id": "8eb8c470-7a18-458a-a47c-3657fd01bb14"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "bddb60b6-7163-4f9f-9eed-d56f004542e1"}}, "type": "ResizeTool", "id": "1814a6a1-5335-4bbd-8a47-9931f8fc2531"}, {"attributes": {"li ...
